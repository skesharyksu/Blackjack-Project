# %% [markdown]
# # Blackjack AI Analysis
#
# Watch the AI analyze hands and see the results of its decisions.

# %%
import time
from blackjack_ai.environment import BlackjackEnv
from blackjack_ai.agents import QLearningAgent

def display_hand_and_decision(dealer_card, player_hand, action, show_full_dealer=False, dealer_hand=None):
    print("\n" + "="*50)
    if show_full_dealer and dealer_hand:
        print(f"Dealer's full hand: {', '.join(str(card) for card in dealer_hand)}")
    else:
        print(f"Dealer shows: {dealer_card}")
    print(f"AI's hand: {', '.join(str(card) for card in player_hand)}")
    
    action_names = ['Stand', 'Hit', 'Double Down']
    print(f"\nAI's decision: {action_names[action]}")
    print("="*50)
    time.sleep(0)  # Pause between hands

def train_agent(training_episodes=10000):
    print("Training AI on", training_episodes, "episodes...")
    env = BlackjackEnv()
    agent = QLearningAgent()
    
    for episode in range(training_episodes):
        state = env.reset()
        done = False
        while not done:
            action = agent.get_action(state, is_training=True)  # Enable training mode
            next_state, reward, done, _ = env.step(action)
            agent.update(state, action, reward, next_state, done)
            state = next_state
        
        if (episode + 1) % 1000 == 0:
            print(f"Training episode {episode + 1}/{training_episodes}, Exploration rate: {agent.epsilon:.4f}")
    
    print("Training complete!")
    agent.save_policy("trained_policy.npy")
    return agent

def analyze_hands(num_hands=100, agent=None):
    env = BlackjackEnv()
    if agent is None:
        agent = QLearningAgent()
        # Try to load pre-trained policy
        if not agent.load_policy("trained_policy.npy"):
            print("No trained policy found. Training new agent...")
            agent = train_agent()
    
    wins = losses = pushes = 0
    print("\nStarting hand analysis...\n")
    
    for hand in range(num_hands):
        state = env.reset()
        done = False
        
        print(f"\nHand {hand + 1}/{num_hands}")
        print(f"Current record - Wins: {wins} | Losses: {losses} | Pushes: {pushes}")
        
        # Get AI's decision for this hand
        action = agent.get_action(state, is_training=False)  # Disable training mode
        
        # Show the initial situation and AI's decision
        display_hand_and_decision(env.dealer_hand[0], env.player_hand, action)
        
        # Execute the AI's decision and show result
        next_state, reward, done, info = env.step(action)
        
        # If the AI hit or doubled and didn't bust, show the updated hand
        while not done and action == 1:  # If AI hit and can still play
            state = next_state
            action = agent.get_action(state, is_training=False)  # Disable training mode
            display_hand_and_decision(env.dealer_hand[0], env.player_hand, action)
            next_state, reward, done, info = env.step(action)
        
        # Show final result with dealer's complete hand
        print("\nFinal Hands:")
        display_hand_and_decision(env.dealer_hand[0], env.player_hand, action, True, env.dealer_hand)
        
        print("\nResult:", end=" ")
        if reward > 0:
            print("WIN! 🎉")
            wins += 1
        elif reward < 0:
            print("LOSS 😢")
            losses += 1
        else:
            print("PUSH (Tie) 🤝")
            pushes += 1
            
        print(f"Exploration Rate (epsilon): {agent.epsilon:.4f}")
        
        if hand == num_hands - 1:
            print("\nFinal Statistics:")
            print(f"Total Wins: {wins}")
            print(f"Total Losses: {losses}")
            print(f"Total Pushes: {pushes}")
            print(f"Win Rate: {(wins/num_hands):.2%}")
            print(f"Final Exploration Rate: {agent.epsilon:.4f}")

# First train the agent, then analyze hands
trained_agent = train_agent()
analyze_hands(100, trained_agent)
# Out:
# Training AI on 10000 episodes...
# Training episode 1000/10000, Exploration rate: 0.5196
# Training episode 2000/10000, Exploration rate: 0.2608
# Training episode 3000/10000, Exploration rate: 0.1291
# Training episode 4000/10000, Exploration rate: 0.0622
# Training episode 5000/10000, Exploration rate: 0.0301
# Training episode 6000/10000, Exploration rate: 0.0144
# Training episode 7000/10000, Exploration rate: 0.0068
# Training episode 8000/10000, Exploration rate: 0.0050
# Training episode 9000/10000, Exploration rate: 0.0050
# Training episode 10000/10000, Exploration rate: 0.0050
# Training complete!
#
# Starting hand analysis...
#
#
# Hand 1/100
# Current record - Wins: 0 | Losses: 0 | Pushes: 0
#
# ==================================================
# Dealer shows: 5 of Spades
# AI's hand: 10 of Clubs, J of Hearts
#
# AI's decision: Stand
# ==================================================
#
# Final Hands:
#
# ==================================================
# Dealer's full hand: 5 of Spades, 9 of Clubs, 8 of Hearts
# AI's hand: 10 of Clubs, J of Hearts
#
# AI's decision: Stand
# ==================================================
#
# Result: WIN! 🎉
# Exploration Rate (epsilon): 0.0050
#
# Hand 2/100
# Current record - Wins: 1 | Losses: 0 | Pushes: 0
#
# ==================================================
# Dealer shows: 3 of Diamonds
# AI's hand: 3 of Clubs, 6 of Clubs
#
# AI's decision: Hit
# ==================================================
#
# ==================================================
# Dealer shows: 3 of Diamonds
# AI's hand: 3 of Clubs, 6 of Clubs, 4 of Clubs
#
# AI's decision: Stand
# ==================================================
#
# Final Hands:
#
# ==================================================
# Dealer's full hand: 3 of Diamonds, 8 of Spades, 6 of Diamonds
# AI's hand: 3 of Clubs, 6 of Clubs, 4 of Clubs
#
# AI's decision: Stand
# ==================================================
#
# Result: LOSS 😢
# Exploration Rate (epsilon): 0.0050
#
# Hand 3/100
# Current record - Wins: 1 | Losses: 1 | Pushes: 0
#
# ==================================================
# Dealer shows: 3 of Clubs
# AI's hand: 6 of Spades, 3 of Hearts
#
# AI's decision: Hit
# ==================================================
#
# ==================================================
# Dealer shows: 3 of Clubs
# AI's hand: 6 of Spades, 3 of Hearts, J of Clubs
#
# AI's decision: Stand
# ==================================================
#
# Final Hands:
#
# ==================================================
# Dealer's full hand: 3 of Clubs, 10 of Clubs, 5 of Diamonds
# AI's hand: 6 of Spades, 3 of Hearts, J of Clubs
#
# AI's decision: Stand
# ==================================================
#
# Result: WIN! 🎉
# Exploration Rate (epsilon): 0.0050
#
# Hand 4/100
# Current record - Wins: 2 | Losses: 1 | Pushes: 0
#
# ==================================================
# Dealer shows: 4 of Hearts
# AI's hand: 5 of Clubs, 7 of Clubs
#
# AI's decision: Hit
# ==================================================
#
# ==================================================
# Dealer shows: 4 of Hearts
# AI's hand: 5 of Clubs, 7 of Clubs, 3 of Hearts
#
# AI's decision: Stand
# ==================================================
#
# Final Hands:
#
# ==================================================
# Dealer's full hand: 4 of Hearts, 10 of Clubs, 9 of Spades
# AI's hand: 5 of Clubs, 7 of Clubs, 3 of Hearts
#
# AI's decision: Stand
# ==================================================
#
# Result: WIN! 🎉
# Exploration Rate (epsilon): 0.0050
#
# Hand 5/100
# Current record - Wins: 3 | Losses: 1 | Pushes: 0
#
# ==================================================
# Dealer shows: Q of Clubs
# AI's hand: 10 of Hearts, A of Clubs
#
# AI's decision: Stand
# ==================================================
#
# Final Hands:
#
# ==================================================
# Dealer's full hand: Q of Clubs, 3 of Spades
# AI's hand: 10 of Hearts, A of Clubs
#
# AI's decision: Stand
# ==================================================
#
# Result: PUSH (Tie) 🤝
# Exploration Rate (epsilon): 0.0050
#
# Hand 6/100
# Current record - Wins: 3 | Losses: 1 | Pushes: 1
#
# ==================================================
# Dealer shows: 7 of Spades
# AI's hand: 10 of Diamonds, A of Spades
#
# AI's decision: Stand
# ==================================================
#
# Final Hands:
#
# ==================================================
# Dealer's full hand: 7 of Spades, Q of Hearts
# AI's hand: 10 of Diamonds, A of Spades
#
# AI's decision: Stand
# ==================================================
#
# Result: PUSH (Tie) 🤝
# Exploration Rate (epsilon): 0.0050
#
# Hand 7/100
# Current record - Wins: 3 | Losses: 1 | Pushes: 2
#
# ==================================================
# Dealer shows: 4 of Diamonds
# AI's hand: K of Spades, 2 of Clubs
#
# AI's decision: Hit
# ==================================================
#
# Final Hands:
#
# ==================================================
# Dealer's full hand: 4 of Diamonds, 6 of Spades
# AI's hand: K of Spades, 2 of Clubs, K of Spades
#
# AI's decision: Hit
# ==================================================
#
# Result: LOSS 😢
# Exploration Rate (epsilon): 0.0050
#
# Hand 8/100
# Current record - Wins: 3 | Losses: 2 | Pushes: 2
#
# ==================================================
# Dealer shows: Q of Hearts
# AI's hand: 6 of Clubs, 9 of Hearts
#
# AI's decision: Hit
# ==================================================
#
# Final Hands:
#
# ==================================================
# Dealer's full hand: Q of Hearts, J of Spades
# AI's hand: 6 of Clubs, 9 of Hearts, Q of Diamonds
#
# AI's decision: Hit
# ==================================================
#
# Result: LOSS 😢
# Exploration Rate (epsilon): 0.0050
#
# Hand 9/100
# Current record - Wins: 3 | Losses: 3 | Pushes: 2
#
# ==================================================
# Dealer shows: 4 of Hearts
# AI's hand: 10 of Diamonds, 9 of Spades
#
# AI's decision: Stand
# ==================================================
#
# Final Hands:
#
# ==================================================
# Dealer's full hand: 4 of Hearts, 10 of Clubs, 9 of Diamonds
# AI's hand: 10 of Diamonds, 9 of Spades
#
# AI's decision: Stand
# ==================================================
#
# Result: WIN! 🎉
# Exploration Rate (epsilon): 0.0050
#
# Hand 10/100
# Current record - Wins: 4 | Losses: 3 | Pushes: 2
#
# ==================================================
# Dealer shows: 8 of Spades
# AI's hand: Q of Clubs, 9 of Hearts
#
# AI's decision: Stand
# ==================================================
#
# Final Hands:
#
# ==================================================
# Dealer's full hand: 8 of Spades, 7 of Clubs, 3 of Diamonds
# AI's hand: Q of Clubs, 9 of Hearts
#
# AI's decision: Stand
# ==================================================
#
# Result: WIN! 🎉
# Exploration Rate (epsilon): 0.0050
#
# Hand 11/100
# Current record - Wins: 5 | Losses: 3 | Pushes: 2
#
# ==================================================
# Dealer shows: 2 of Spades
# AI's hand: 5 of Diamonds, J of Diamonds
#
# AI's decision: Hit
# ==================================================
#
# Final Hands:
#
# ==================================================
# Dealer's full hand: 2 of Spades, 4 of Hearts
# AI's hand: 5 of Diamonds, J of Diamonds, 9 of Clubs
#
# AI's decision: Hit
# ==================================================
#
# Result: LOSS 😢
# Exploration Rate (epsilon): 0.0050
#
# Hand 12/100
# Current record - Wins: 5 | Losses: 4 | Pushes: 2
#
# ==================================================
# Dealer shows: K of Clubs
# AI's hand: 4 of Spades, 2 of Spades
#
# AI's decision: Hit
# ==================================================
#
# ==================================================
# Dealer shows: K of Clubs
# AI's hand: 4 of Spades, 2 of Spades, 4 of Diamonds
#
# AI's decision: Hit
# ==================================================
#
# ==================================================
# Dealer shows: K of Clubs
# AI's hand: 4 of Spades, 2 of Spades, 4 of Diamonds, 5 of Hearts
#
# AI's decision: Hit
# ==================================================
#
# Final Hands:
#
# ==================================================
# Dealer's full hand: K of Clubs, 8 of Clubs
# AI's hand: 4 of Spades, 2 of Spades, 4 of Diamonds, 5 of Hearts, 9 of Clubs
#
# AI's decision: Hit
# ==================================================
#
# Result: LOSS 😢
# Exploration Rate (epsilon): 0.0050
#
# Hand 13/100
# Current record - Wins: 5 | Losses: 5 | Pushes: 2
#
# ==================================================
# Dealer shows: 8 of Diamonds
# AI's hand: 7 of Hearts, 5 of Spades
#
# AI's decision: Stand
# ==================================================
#
# Final Hands:
#
# ==================================================
# Dealer's full hand: 8 of Diamonds, J of Hearts
# AI's hand: 7 of Hearts, 5 of Spades
#
# AI's decision: Stand
# ==================================================
