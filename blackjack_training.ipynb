# %% [markdown]
# # Blackjack AI Analysis
#
# Watch the AI analyze hands and see the results of its decisions.

# %%
import time
from blackjack_ai.environment import BlackjackEnv
from blackjack_ai.agents import QLearningAgent

def display_hand_and_decision(dealer_card, player_hand, action, show_full_dealer=False, dealer_hand=None):
    print("\n" + "="*50)
    if show_full_dealer and dealer_hand:
        print(f"Dealer's full hand: {', '.join(str(card) for card in dealer_hand)}")
    else:
        print(f"Dealer shows: {dealer_card}")
    print(f"AI's hand: {', '.join(str(card) for card in player_hand)}")
    
    action_names = ['Stand', 'Hit', 'Double Down']
    print(f"\nAI's decision: {action_names[action]}")
    print("="*50)
    time.sleep(0)  # Pause between hands

def train_agent(training_episodes=10000):
    print("Training AI on", training_episodes, "episodes...")
    env = BlackjackEnv()
    agent = QLearningAgent()
    
    for episode in range(training_episodes):
        state = env.reset()
        done = False
        while not done:
            action = agent.get_action(state, is_training=True)  # Enable training mode
            next_state, reward, done, _ = env.step(action)
            agent.update(state, action, reward, next_state, done)
            state = next_state
        
        if (episode + 1) % 1000 == 0:
            print(f"Training episode {episode + 1}/{training_episodes}, Exploration rate: {agent.exploration_rate:.4f}")
    
    print("Training complete!")
    agent.save_policy("trained_policy.npy")
    return agent

def analyze_hands(num_hands=100, agent=None):
    env = BlackjackEnv()
    if agent is None:
        agent = QLearningAgent()
        # Try to load pre-trained policy
        if not agent.load_policy("trained_policy.npy"):
            print("No trained policy found. Training new agent...")
            agent = train_agent()
    
    wins = losses = pushes = 0
    print("\nStarting hand analysis...\n")
    
    for hand in range(num_hands):
        state = env.reset()
        done = False
        
        print(f"\nHand {hand + 1}/{num_hands}")
        print(f"Current record - Wins: {wins} | Losses: {losses} | Pushes: {pushes}")
        
        # Get AI's decision for this hand
        action = agent.get_action(state, is_training=False)  # Disable training mode
        
        # Show the initial situation and AI's decision
        display_hand_and_decision(env.dealer_hand[0], env.player_hand, action)
        
        # Execute the AI's decision and show result
        next_state, reward, done, info = env.step(action)
        
        # If the AI hit or doubled and didn't bust, show the updated hand
        while not done and action == 1:  # If AI hit and can still play
            state = next_state
            action = agent.get_action(state, is_training=False)  # Disable training mode
            display_hand_and_decision(env.dealer_hand[0], env.player_hand, action)
            next_state, reward, done, info = env.step(action)
        
        # Show final result with dealer's complete hand
        print("\nFinal Hands:")
        display_hand_and_decision(env.dealer_hand[0], env.player_hand, action, True, env.dealer_hand)
        
        print("\nResult:", end=" ")
        if reward > 0:
            print("WIN! 🎉")
            wins += 1
        elif reward < 0:
            print("LOSS 😢")
            losses += 1
        else:
            print("PUSH (Tie) 🤝")
            pushes += 1
            
        print(f"Exploration Rate (epsilon): {agent.exploration_rate:.4f}")
        
        if hand == num_hands - 1:
            print("\nFinal Statistics:")
            print(f"Total Wins: {wins}")
            print(f"Total Losses: {losses}")
            print(f"Total Pushes: {pushes}")
            print(f"Win Rate: {(wins/num_hands):.2%}")
            print(f"Final Exploration Rate: {agent.exploration_rate:.4f}")

# First train the agent, then analyze hands
trained_agent = train_agent()
analyze_hands(100, trained_agent)
# Out:
# Training AI on 10000 episodes...
# Training episode 1000/10000, Exploration rate: 0.0100
# Training episode 2000/10000, Exploration rate: 0.0100
# Training episode 3000/10000, Exploration rate: 0.0100
# Training episode 4000/10000, Exploration rate: 0.0100
# Training episode 5000/10000, Exploration rate: 0.0100
# Training episode 6000/10000, Exploration rate: 0.0100
# Training episode 7000/10000, Exploration rate: 0.0100
# Training episode 8000/10000, Exploration rate: 0.0100
# Training episode 9000/10000, Exploration rate: 0.0100
# Training episode 10000/10000, Exploration rate: 0.0100
# Training complete!
#
# Starting hand analysis...
#
#
# Hand 1/100
# Current record - Wins: 0 | Losses: 0 | Pushes: 0
#
# ==================================================
# Dealer shows: 10 of Diamonds
# AI's hand: A of Spades, 4 of Clubs
#
# AI's decision: Hit
# ==================================================
#
# ==================================================
# Dealer shows: 10 of Diamonds
# AI's hand: A of Spades, 4 of Clubs, K of Spades
#
# AI's decision: Hit
# ==================================================
#
# Final Hands:
#
# ==================================================
# Dealer's full hand: 10 of Diamonds, 9 of Hearts
# AI's hand: A of Spades, 4 of Clubs, K of Spades, J of Spades
#
# AI's decision: Hit
# ==================================================
#
# Result: LOSS 😢
# Exploration Rate (epsilon): 0.0100
#
# Hand 2/100
# Current record - Wins: 0 | Losses: 1 | Pushes: 0
#
# ==================================================
# Dealer shows: K of Diamonds
# AI's hand: K of Spades, 3 of Clubs
#
# AI's decision: Hit
# ==================================================
#
# ==================================================
# Dealer shows: K of Diamonds
# AI's hand: K of Spades, 3 of Clubs, 7 of Hearts
#
# AI's decision: Stand
# ==================================================
#
# Final Hands:
#
# ==================================================
# Dealer's full hand: K of Diamonds, 6 of Clubs, 7 of Hearts
# AI's hand: K of Spades, 3 of Clubs, 7 of Hearts
#
# AI's decision: Stand
# ==================================================
#
# Result: WIN! 🎉
# Exploration Rate (epsilon): 0.0100
#
# Hand 3/100
# Current record - Wins: 1 | Losses: 1 | Pushes: 0
#
# ==================================================
# Dealer shows: 9 of Clubs
# AI's hand: 6 of Spades, 9 of Diamonds
#
# AI's decision: Double Down
# ==================================================
#
# Final Hands:
#
# ==================================================
# Dealer's full hand: 9 of Clubs, 6 of Spades
# AI's hand: 6 of Spades, 9 of Diamonds, 8 of Diamonds
#
# AI's decision: Double Down
# ==================================================
#
# Result: LOSS 😢
# Exploration Rate (epsilon): 0.0100
#
# Hand 4/100
# Current record - Wins: 1 | Losses: 2 | Pushes: 0
#
# ==================================================
# Dealer shows: 3 of Diamonds
# AI's hand: 7 of Diamonds, 8 of Diamonds
#
# AI's decision: Stand
# ==================================================
#
# Final Hands:
#
# ==================================================
# Dealer's full hand: 3 of Diamonds, 8 of Clubs, 4 of Spades, 6 of Clubs
# AI's hand: 7 of Diamonds, 8 of Diamonds
#
# AI's decision: Stand
# ==================================================
#
# Result: LOSS 😢
# Exploration Rate (epsilon): 0.0100
#
# Hand 5/100
# Current record - Wins: 1 | Losses: 3 | Pushes: 0
#
# ==================================================
# Dealer shows: 7 of Diamonds
# AI's hand: K of Hearts, J of Hearts
#
# AI's decision: Stand
# ==================================================
#
# Final Hands:
#
# ==================================================
# Dealer's full hand: 7 of Diamonds, 4 of Diamonds, 6 of Hearts
# AI's hand: K of Hearts, J of Hearts
#
# AI's decision: Stand
# ==================================================
#
# Result: WIN! 🎉
# Exploration Rate (epsilon): 0.0100
#
# Hand 6/100
# Current record - Wins: 2 | Losses: 3 | Pushes: 0
#
# ==================================================
# Dealer shows: Q of Hearts
# AI's hand: 10 of Diamonds, Q of Diamonds
#
# AI's decision: Stand
# ==================================================
#
# Final Hands:
#
# ==================================================
# Dealer's full hand: Q of Hearts, 7 of Hearts
# AI's hand: 10 of Diamonds, Q of Diamonds
#
# AI's decision: Stand
# ==================================================
#
# Result: WIN! 🎉
# Exploration Rate (epsilon): 0.0100
#
# Hand 7/100
# Current record - Wins: 3 | Losses: 3 | Pushes: 0
#
# ==================================================
# Dealer shows: 3 of Spades
# AI's hand: 5 of Spades, Q of Hearts
#
# AI's decision: Stand
# ==================================================
#
# Final Hands:
#
# ==================================================
# Dealer's full hand: 3 of Spades, 8 of Hearts, 3 of Diamonds, 2 of Diamonds, J of Clubs
# AI's hand: 5 of Spades, Q of Hearts
#
# AI's decision: Stand
# ==================================================
#
# Result: WIN! 🎉
# Exploration Rate (epsilon): 0.0100
#
# Hand 8/100
# Current record - Wins: 4 | Losses: 3 | Pushes: 0
#
# ==================================================
# Dealer shows: 10 of Clubs
# AI's hand: 4 of Hearts, A of Diamonds
#
# AI's decision: Hit
# ==================================================
#
# ==================================================
# Dealer shows: 10 of Clubs
# AI's hand: 4 of Hearts, A of Diamonds, K of Diamonds
#
# AI's decision: Hit
# ==================================================
#
# Final Hands:
#
# ==================================================
# Dealer's full hand: 10 of Clubs, 9 of Clubs
# AI's hand: 4 of Hearts, A of Diamonds, K of Diamonds, K of Diamonds
#
# AI's decision: Hit
# ==================================================
#
# Result: LOSS 😢
# Exploration Rate (epsilon): 0.0100
#
# Hand 9/100
# Current record - Wins: 4 | Losses: 4 | Pushes: 0
#
# ==================================================
# Dealer shows: 2 of Diamonds
# AI's hand: 8 of Diamonds, 4 of Spades
#
# AI's decision: Hit
# ==================================================
#
# Final Hands:
#
# ==================================================
# Dealer's full hand: 2 of Diamonds, Q of Clubs
# AI's hand: 8 of Diamonds, 4 of Spades, Q of Hearts
#
# AI's decision: Hit
# ==================================================
#
# Result: LOSS 😢
# Exploration Rate (epsilon): 0.0100
#
# Hand 10/100
# Current record - Wins: 4 | Losses: 5 | Pushes: 0
#
# ==================================================
# Dealer shows: 6 of Spades
# AI's hand: 4 of Diamonds, 5 of Hearts
#
# AI's decision: Hit
# ==================================================
#
# ==================================================
# Dealer shows: 6 of Spades
# AI's hand: 4 of Diamonds, 5 of Hearts, 6 of Clubs
#
# AI's decision: Hit
# ==================================================
#
# ==================================================
# Dealer shows: 6 of Spades
# AI's hand: 4 of Diamonds, 5 of Hearts, 6 of Clubs, 3 of Diamonds
#
# AI's decision: Stand
# ==================================================
#
# Final Hands:
#
# ==================================================
# Dealer's full hand: 6 of Spades, 9 of Spades, J of Diamonds
# AI's hand: 4 of Diamonds, 5 of Hearts, 6 of Clubs, 3 of Diamonds
#
# AI's decision: Stand
# ==================================================
#
# Result: WIN! 🎉
# Exploration Rate (epsilon): 0.0100
#
# Hand 11/100
# Current record - Wins: 5 | Losses: 5 | Pushes: 0
#
# ==================================================
# Dealer shows: 9 of Diamonds
# AI's hand: 7 of Diamonds, J of Spades
#
# AI's decision: Hit
# ==================================================
#
# ==================================================
# Dealer shows: 9 of Diamonds
# AI's hand: 7 of Diamonds, J of Spades, A of Spades
#
# AI's decision: Stand
# ==================================================
#
# Final Hands:
#
# ==================================================
# Dealer's full hand: 9 of Diamonds, 10 of Hearts
# AI's hand: 7 of Diamonds, J of Spades, A of Spades
#
# AI's decision: Stand
# ==================================================
#
# Result: LOSS 😢
# Exploration Rate (epsilon): 0.0100
#
# Hand 12/100
# Current record - Wins: 5 | Losses: 6 | Pushes: 0
#
# ==================================================
# Dealer shows: 8 of Diamonds
# AI's hand: 7 of Spades, 2 of Clubs
#
# AI's decision: Hit
# ==================================================
#
# ==================================================
# Dealer shows: 8 of Diamonds
# AI's hand: 7 of Spades, 2 of Clubs, 3 of Spades
#
# AI's decision: Hit
# ==================================================
#
# ==================================================
# Dealer shows: 8 of Diamonds
# AI's hand: 7 of Spades, 2 of Clubs, 3 of Spades, 9 of Spades
#
# AI's decision: Stand
# ==================================================
#
# Final Hands:
#
# ==================================================
# Dealer's full hand: 8 of Diamonds, 4 of Clubs, 5 of Hearts
# AI's hand: 7 of Spades, 2 of Clubs, 3 of Spades, 9 of Spades
#
# AI's decision: Stand
# ==================================================
#
# Result: WIN! 🎉
# Exploration Rate (epsilon): 0.0100
#
# Hand 13/100
# Current record - Wins: 6 | Losses: 6 | Pushes: 0
#
# ==================================================
# Dealer shows: 5 of Clubs
# AI's hand: 6 of Hearts, 9 of Hearts
#
# AI's decision: Double Down
# ==================================================
#
# Final Hands:
#
# ==================================================
# Dealer's full hand: 5 of Clubs, 3 of Hearts, 10 of Hearts
# AI's hand: 6 of Hearts, 9 of Hearts, 5 of Diamonds
#
# AI's decision: Double Down
# ==================================================
#
# Result: WIN! 🎉
# Exploration Rate (epsilon): 0.0100
#
# Hand 14/100
# Current record - Wins: 7 | Losses: 6 | Pushes: 0
#
# ==================================================
# Dealer shows: 5 of Hearts
# AI's hand: 6 of Clubs, 4 of Clubs
#
# AI's decision: Hit
# ==================================================
#
# ==================================================
# Dealer shows: 5 of Hearts
# AI's hand: 6 of Clubs, 4 of Clubs, 2 of Spades
#
# AI's decision: Double Down
# ==================================================
#
# Final Hands:
#
# ==================================================
# Dealer's full hand: 5 of Hearts, 3 of Clubs
# AI's hand: 6 of Clubs, 4 of Clubs, 2 of Spades
#
# AI's decision: Double Down
# ==================================================
#
# Result: LOSS 😢
# Exploration Rate (epsilon): 0.0100
#
# Hand 15/100
# Current record - Wins: 7 | Losses: 7 | Pushes: 0
#
# ==================================================
# Dealer shows: 8 of Hearts
# AI's hand: Q of Spades, Q of Diamonds
#
# AI's decision: Stand
# ==================================================
#
# Final Hands:
#
# ==================================================
# Dealer's full hand: 8 of Hearts, Q of Spades
# AI's hand: Q of Spades, Q of Diamonds
#
# AI's decision: Stand
# ==================================================
#
# Result: WIN! 🎉
# Exploration Rate (epsilon): 0.0100
#
# Hand 16/100
# Current record - Wins: 8 | Losses: 7 | Pushes: 0
#
# ==================================================
# Dealer shows: K of Clubs
# AI's hand: 5 of Hearts, 4 of Spades
#
# AI's decision: Hit
# ==================================================
#
# ==================================================
# Dealer shows: K of Clubs
# AI's hand: 5 of Hearts, 4 of Spades, 5 of Diamonds
#
# AI's decision: Hit
# ==================================================
#
# ==================================================
# Dealer shows: K of Clubs
# AI's hand: 5 of Hearts, 4 of Spades, 5 of Diamonds, A of Hearts
#
# AI's decision: Hit
# ==================================================
#
# Final Hands:
#
# ==================================================
# Dealer's full hand: K of Clubs, 7 of Spades
# AI's hand: 5 of Hearts, 4 of Spades, 5 of Diamonds, A of Hearts, Q of Hearts
#
# AI's decision: Hit
# ==================================================
#
# Result: LOSS 😢
# Exploration Rate (epsilon): 0.0100
#
# Hand 17/100
# Current record - Wins: 8 | Losses: 8 | Pushes: 0
#
# ==================================================
# Dealer shows: 7 of Clubs
# AI's hand: 10 of Spades, Q of Spades
#
# AI's decision: Stand
# ==================================================
#
# Final Hands:
#
# ==================================================
# Dealer's full hand: 7 of Clubs, J of Hearts
# AI's hand: 10 of Spades, Q of Spades
#
# AI's decision: Stand
# ==================================================
#
# Result: WIN! 🎉
# Exploration Rate (epsilon): 0.0100
#
# Hand 18/100
# Current record - Wins: 9 | Losses: 8 | Pushes: 0
#
# ==================================================
# Dealer shows: 10 of Clubs
# AI's hand: J of Diamonds, 8 of Spades
#
# AI's decision: Stand
# ==================================================
#
# Final Hands:
#
# ==================================================
# Dealer's full hand: 10 of Clubs, 4 of Spades, 8 of Spades
# AI's hand: J of Diamonds, 8 of Spades
#
# AI's decision: Stand
# ==================================================
#
# Result: WIN! 🎉
# Exploration Rate (epsilon): 0.0100
#
# Hand 19/100
# Current record - Wins: 10 | Losses: 8 | Pushes: 0
#
# ==================================================
# Dealer shows: 3 of Spades
# AI's hand: 2 of Hearts, A of Diamonds
#
# AI's decision: Hit
# ==================================================
#
# ==================================================
# Dealer shows: 3 of Spades
# AI's hand: 2 of Hearts, A of Diamonds, 4 of Diamonds
#
# AI's decision: Hit
# ==================================================
#
# ==================================================
# Dealer shows: 3 of Spades
# AI's hand: 2 of Hearts, A of Diamonds, 4 of Diamonds, 8 of Clubs
#
# AI's decision: Stand
# ==================================================
#
# Final Hands:
#
# ==================================================
# Dealer's full hand: 3 of Spades, 6 of Hearts, J of Spades
# AI's hand: 2 of Hearts, A of Diamonds, 4 of Diamonds, 8 of Clubs
#
# AI's decision: Stand
# ==================================================
#
# Result: LOSS 😢
# Exploration Rate (epsilon): 0.0100
#
# Hand 20/100
# Current record - Wins: 10 | Losses: 9 | Pushes: 0
#
# ==================================================
# Dealer shows: 10 of Diamonds
# AI's hand: 2 of Hearts, K of Clubs
#
# AI's decision: Hit
# ==================================================
#
# ==================================================
# Dealer shows: 10 of Diamonds
# AI's hand: 2 of Hearts, K of Clubs, 2 of Clubs
#
# AI's decision: Hit
# ==================================================
#
# ==================================================
# Dealer shows: 10 of Diamonds
# AI's hand: 2 of Hearts, K of Clubs, 2 of Clubs, 5 of Clubs
#
# AI's decision: Stand
# ==================================================
#
# Final Hands:
#
# ==================================================
# Dealer's full hand: 10 of Diamonds, 10 of Spades
# AI's hand: 2 of Hearts, K of Clubs, 2 of Clubs, 5 of Clubs
#
# AI's decision: Stand
# ==================================================
#
# Result: LOSS 😢
# Exploration Rate (epsilon): 0.0100
#
# Hand 21/100
# Current record - Wins: 10 | Losses: 10 | Pushes: 0
#
# ==================================================
# Dealer shows: J of Clubs
# AI's hand: 6 of Diamonds, 7 of Clubs
#
# AI's decision: Hit
# ==================================================
#
# Final Hands:
#
# ==================================================
# Dealer's full hand: J of Clubs, J of Clubs
# AI's hand: 6 of Diamonds, 7 of Clubs, 9 of Diamonds
#
# AI's decision: Hit
# ==================================================
#
# Result: LOSS 😢
# Exploration Rate (epsilon): 0.0100
#
# Hand 22/100
# Current record - Wins: 10 | Losses: 11 | Pushes: 0
#
# ==================================================
# Dealer shows: 2 of Diamonds
# AI's hand: 2 of Clubs, 9 of Diamonds
#
# AI's decision: Hit
# ==================================================
#
# ==================================================
# Dealer shows: 2 of Diamonds
# AI's hand: 2 of Clubs, 9 of Diamonds, 3 of Diamonds
#
# AI's decision: Hit
# ==================================================
#
# ==================================================
# Dealer shows: 2 of Diamonds
# AI's hand: 2 of Clubs, 9 of Diamonds, 3 of Diamonds, 7 of Clubs
#
# AI's decision: Stand
# ==================================================
#
# Final Hands:
#
# ==================================================
# Dealer's full hand: 2 of Diamonds, Q of Diamonds, J of Diamonds
# AI's hand: 2 of Clubs, 9 of Diamonds, 3 of Diamonds, 7 of Clubs
#
# AI's decision: Stand
# ==================================================
#
# Result: WIN! 🎉
# Exploration Rate (epsilon): 0.0100
#
# Hand 23/100
# Current record - Wins: 11 | Losses: 11 | Pushes: 0
#
# ==================================================
# Dealer shows: 7 of Clubs
# AI's hand: 6 of Spades, J of Diamonds
#
# AI's decision: Hit
# ==================================================
#
# ==================================================
# Dealer shows: 7 of Clubs
# AI's hand: 6 of Spades, J of Diamonds, 5 of Diamonds
#
# AI's decision: Stand
# ==================================================
#
# Final Hands:
#
# ==================================================
# Dealer's full hand: 7 of Clubs, Q of Clubs
# AI's hand: 6 of Spades, J of Diamonds, 5 of Diamonds
#
# AI's decision: Stand
# ==================================================
#
# Result: WIN! 🎉
# Exploration Rate (epsilon): 0.0100
#
# Hand 24/100
# Current record - Wins: 12 | Losses: 11 | Pushes: 0
#
# ==================================================
# Dealer shows: A of Hearts
# AI's hand: K of Clubs, 3 of Clubs
#
# AI's decision: Hit
# ==================================================
#
# ==================================================
# Dealer shows: A of Hearts
# AI's hand: K of Clubs, 3 of Clubs, A of Diamonds
#
# AI's decision: Hit
# ==================================================
#
# ==================================================
# Dealer shows: A of Hearts
# AI's hand: K of Clubs, 3 of Clubs, A of Diamonds, 5 of Spades
#
# AI's decision: Stand
# ==================================================
#
# Final Hands:
#
# ==================================================
# Dealer's full hand: A of Hearts, 8 of Clubs
# AI's hand: K of Clubs, 3 of Clubs, A of Diamonds, 5 of Spades
#
# AI's decision: Stand
# ==================================================
#
# Result: PUSH (Tie) 🤝
# Exploration Rate (epsilon): 0.0100
#
# Hand 25/100
# Current record - Wins: 12 | Losses: 11 | Pushes: 1
#
# ==================================================
# Dealer shows: 2 of Clubs
# AI's hand: K of Hearts, A of Diamonds
#
# AI's decision: Stand
# ==================================================
#
# Final Hands:
#
# ==================================================
# Dealer's full hand: 2 of Clubs, 5 of Spades
# AI's hand: K of Hearts, A of Diamonds
#
# AI's decision: Stand
# ==================================================
#
# Result: PUSH (Tie) 🤝
# Exploration Rate (epsilon): 0.0100
#
# Hand 26/100
# Current record - Wins: 12 | Losses: 11 | Pushes: 2
#
# ==================================================
# Dealer shows: 2 of Spades
# AI's hand: K of Diamonds, 4 of Diamonds
#
# AI's decision: Hit
# ==================================================
#
# Final Hands:
#
# ==================================================
# Dealer's full hand: 2 of Spades, J of Clubs
# AI's hand: K of Diamonds, 4 of Diamonds, 9 of Clubs
#
# AI's decision: Hit
# ==================================================
#
# Result: LOSS 😢
# Exploration Rate (epsilon): 0.0100
#
# Hand 27/100
# Current record - Wins: 12 | Losses: 12 | Pushes: 2
#
# ==================================================
# Dealer shows: 2 of Spades
# AI's hand: K of Spades, Q of Clubs
#
# AI's decision: Stand
# ==================================================
#
# Final Hands:
#
# ==================================================
# Dealer's full hand: 2 of Spades, A of Spades, Q of Clubs, K of Spades
# AI's hand: K of Spades, Q of Clubs
#
# AI's decision: Stand
# ==================================================
#
# Result: WIN! 🎉
# Exploration Rate (epsilon): 0.0100
#
# Hand 28/100
# Current record - Wins: 13 | Losses: 12 | Pushes: 2
#
# ==================================================
# Dealer shows: 10 of Hearts
# AI's hand: A of Clubs, 9 of Spades
#
# AI's decision: Stand
# ==================================================
#
# Final Hands:
#
# ==================================================
# Dealer's full hand: 10 of Hearts, A of Hearts
# AI's hand: A of Clubs, 9 of Spades
#
# AI's decision: Stand
# ==================================================
#
# Result: LOSS 😢
# Exploration Rate (epsilon): 0.0100
#
# Hand 29/100
# Current record - Wins: 13 | Losses: 13 | Pushes: 2
#
# ==================================================
# Dealer shows: 6 of Diamonds
# AI's hand: Q of Diamonds, A of Clubs
#
# AI's decision: Stand
# ==================================================
#
# Final Hands:
#
# ==================================================
# Dealer's full hand: 6 of Diamonds, 9 of Hearts
# AI's hand: Q of Diamonds, A of Clubs
#
# AI's decision: Stand
# ==================================================
#
# Result: PUSH (Tie) 🤝
# Exploration Rate (epsilon): 0.0100
#
# Hand 30/100
# Current record - Wins: 13 | Losses: 13 | Pushes: 3
#
# ==================================================
# Dealer shows: 6 of Hearts
# AI's hand: 4 of Clubs, 9 of Spades
#
# AI's decision: Hit
# ==================================================
#
# ==================================================
# Dealer shows: 6 of Hearts
# AI's hand: 4 of Clubs, 9 of Spades, A of Clubs
#
# AI's decision: Stand
# ==================================================
#
# Final Hands:
#
# ==================================================
# Dealer's full hand: 6 of Hearts, 3 of Hearts, 10 of Clubs
# AI's hand: 4 of Clubs, 9 of Spades, A of Clubs
#
# AI's decision: Stand
# ==================================================
#
# Result: LOSS 😢
# Exploration Rate (epsilon): 0.0100
#
# Hand 31/100
# Current record - Wins: 13 | Losses: 14 | Pushes: 3
#
# ==================================================
# Dealer shows: 7 of Diamonds
# AI's hand: 6 of Diamonds, 10 of Spades
#
# AI's decision: Hit
# ==================================================
#
# Final Hands:
#
# ==================================================
# Dealer's full hand: 7 of Diamonds, 10 of Clubs
# AI's hand: 6 of Diamonds, 10 of Spades, 10 of Hearts
#
# AI's decision: Hit
# ==================================================
#
# Result: LOSS 😢
# Exploration Rate (epsilon): 0.0100
#
# Hand 32/100
# Current record - Wins: 13 | Losses: 15 | Pushes: 3
#
# ==================================================
# Dealer shows: 3 of Clubs
# AI's hand: 5 of Diamonds, 4 of Hearts
#
# AI's decision: Hit
# ==================================================
#
# ==================================================
# Dealer shows: 3 of Clubs
# AI's hand: 5 of Diamonds, 4 of Hearts, 6 of Diamonds
#
# AI's decision: Stand
# ==================================================
#
# Final Hands:
#
# ==================================================
# Dealer's full hand: 3 of Clubs, 5 of Clubs, 10 of Diamonds
# AI's hand: 5 of Diamonds, 4 of Hearts, 6 of Diamonds
#
# AI's decision: Stand
# ==================================================
#
# Result: LOSS 😢
# Exploration Rate (epsilon): 0.0100
#
# Hand 33/100
# Current record - Wins: 13 | Losses: 16 | Pushes: 3
#
# ==================================================
# Dealer shows: 7 of Spades
# AI's hand: 10 of Spades, A of Hearts
#
# AI's decision: Stand
# ==================================================
#
# Final Hands:
#
# ==================================================
# Dealer's full hand: 7 of Spades, 3 of Hearts
# AI's hand: 10 of Spades, A of Hearts
#
# AI's decision: Stand
# ==================================================
#
# Result: PUSH (Tie) 🤝
# Exploration Rate (epsilon): 0.0100
#
# Hand 34/100
# Current record - Wins: 13 | Losses: 16 | Pushes: 4
#
# ==================================================
# Dealer shows: A of Spades
# AI's hand: 7 of Spades, K of Clubs
#
# AI's decision: Stand
# ==================================================
#
# Final Hands:
#
# ==================================================
# Dealer's full hand: A of Spades, 3 of Spades, J of Spades, 4 of Hearts
# AI's hand: 7 of Spades, K of Clubs
#
# AI's decision: Stand
# ==================================================
#
# Result: LOSS 😢
# Exploration Rate (epsilon): 0.0100
#
# Hand 35/100
# Current record - Wins: 13 | Losses: 17 | Pushes: 4
#
# ==================================================
# Dealer shows: 8 of Spades
# AI's hand: 7 of Hearts, A of Clubs
#
# AI's decision: Stand
# ==================================================
#
# Final Hands:
#
# ==================================================
# Dealer's full hand: 8 of Spades, K of Hearts
# AI's hand: 7 of Hearts, A of Clubs
#
# AI's decision: Stand
# ==================================================
#
# Result: PUSH (Tie) 🤝
# Exploration Rate (epsilon): 0.0100
#
# Hand 36/100
# Current record - Wins: 13 | Losses: 17 | Pushes: 5
#
# ==================================================
# Dealer shows: 5 of Spades
# AI's hand: 2 of Diamonds, 9 of Clubs
#
# AI's decision: Hit
# ==================================================
#
# ==================================================
# Dealer shows: 5 of Spades
# AI's hand: 2 of Diamonds, 9 of Clubs, 3 of Hearts
#
# AI's decision: Stand
# ==================================================
#
# Final Hands:
#
# ==================================================
# Dealer's full hand: 5 of Spades, 2 of Hearts, 2 of Spades, 8 of Hearts
# AI's hand: 2 of Diamonds, 9 of Clubs, 3 of Hearts
#
# AI's decision: Stand
# ==================================================
#
# Result: LOSS 😢
# Exploration Rate (epsilon): 0.0100
#
# Hand 37/100
# Current record - Wins: 13 | Losses: 18 | Pushes: 5
#
# ==================================================
# Dealer shows: 4 of Hearts
# AI's hand: 8 of Hearts, K of Hearts
#
# AI's decision: Stand
# ==================================================
#
# Final Hands:
#
# ==================================================
# Dealer's full hand: 4 of Hearts, 9 of Hearts, 2 of Hearts, 5 of Clubs
# AI's hand: 8 of Hearts, K of Hearts
#
# AI's decision: Stand
# ==================================================
#
# Result: LOSS 😢
# Exploration Rate (epsilon): 0.0100
#
# Hand 38/100
# Current record - Wins: 13 | Losses: 19 | Pushes: 5
#
# ==================================================
# Dealer shows: J of Hearts
# AI's hand: J of Hearts, Q of Spades
#
# AI's decision: Stand
# ==================================================
#
# Final Hands:
#
# ==================================================
# Dealer's full hand: J of Hearts, 8 of Clubs
# AI's hand: J of Hearts, Q of Spades
#
# AI's decision: Stand
# ==================================================
#
# Result: WIN! 🎉
# Exploration Rate (epsilon): 0.0100
#
# Hand 39/100
# Current record - Wins: 14 | Losses: 19 | Pushes: 5
#
# ==================================================
# Dealer shows: 3 of Hearts
# AI's hand: 8 of Spades, K of Spades
#
# AI's decision: Stand
# ==================================================
#
# Final Hands:
#
# ==================================================
# Dealer's full hand: 3 of Hearts, J of Hearts, A of Diamonds, Q of Clubs
# AI's hand: 8 of Spades, K of Spades
#
# AI's decision: Stand
# ==================================================
#
# Result: WIN! 🎉
# Exploration Rate (epsilon): 0.0100
#
# Hand 40/100
# Current record - Wins: 15 | Losses: 19 | Pushes: 5
#
# ==================================================
# Dealer shows: 9 of Spades
# AI's hand: Q of Diamonds, 9 of Hearts
#
# AI's decision: Stand
# ==================================================
#
# Final Hands:
#
# ==================================================
# Dealer's full hand: 9 of Spades, 2 of Diamonds, 7 of Spades
# AI's hand: Q of Diamonds, 9 of Hearts
#
# AI's decision: Stand
# ==================================================
#
# Result: WIN! 🎉
# Exploration Rate (epsilon): 0.0100
#
# Hand 41/100
# Current record - Wins: 16 | Losses: 19 | Pushes: 5
#
# ==================================================
# Dealer shows: 8 of Clubs
# AI's hand: J of Spades, 8 of Hearts
#
# AI's decision: Stand
# ==================================================
#
# Final Hands:
#
# ==================================================
# Dealer's full hand: 8 of Clubs, Q of Spades
# AI's hand: J of Spades, 8 of Hearts
#
# AI's decision: Stand
# ==================================================
#
# Result: PUSH (Tie) 🤝
# Exploration Rate (epsilon): 0.0100
#
# Hand 42/100
# Current record - Wins: 16 | Losses: 19 | Pushes: 6
#
# ==================================================
# Dealer shows: 5 of Diamonds
# AI's hand: J of Clubs, Q of Hearts
#
# AI's decision: Stand
# ==================================================
#
# Final Hands:
#
# ==================================================
# Dealer's full hand: 5 of Diamonds, 3 of Diamonds, A of Clubs
# AI's hand: J of Clubs, Q of Hearts
#
# AI's decision: Stand
# ==================================================
#
# Result: WIN! 🎉
# Exploration Rate (epsilon): 0.0100
#
# Hand 43/100
# Current record - Wins: 17 | Losses: 19 | Pushes: 6
#
# ==================================================
# Dealer shows: 3 of Clubs
# AI's hand: 9 of Diamonds, 4 of Clubs
#
# AI's decision: Hit
# ==================================================
#
# ==================================================
# Dealer shows: 3 of Clubs
# AI's hand: 9 of Diamonds, 4 of Clubs, 4 of Hearts
#
# AI's decision: Stand
# ==================================================
#
# Final Hands:
#
# ==================================================
# Dealer's full hand: 3 of Clubs, 2 of Hearts, 8 of Spades, K of Diamonds
# AI's hand: 9 of Diamonds, 4 of Clubs, 4 of Hearts
#
# AI's decision: Stand
# ==================================================
#
# Result: WIN! 🎉
# Exploration Rate (epsilon): 0.0100
#
# Hand 44/100
# Current record - Wins: 18 | Losses: 19 | Pushes: 6
#
# ==================================================
# Dealer shows: 6 of Clubs
# AI's hand: 2 of Spades, 5 of Clubs
#
# AI's decision: Hit
# ==================================================
#
# ==================================================
# Dealer shows: 6 of Clubs
# AI's hand: 2 of Spades, 5 of Clubs, 6 of Spades
#
# AI's decision: Hit
# ==================================================
#
# ==================================================
# Dealer shows: 6 of Clubs
# AI's hand: 2 of Spades, 5 of Clubs, 6 of Spades, 6 of Hearts
#
# AI's decision: Stand
# ==================================================
#
# Final Hands:
#
# ==================================================
# Dealer's full hand: 6 of Clubs, 8 of Diamonds, J of Diamonds
# AI's hand: 2 of Spades, 5 of Clubs, 6 of Spades, 6 of Hearts
#
# AI's decision: Stand
# ==================================================
#
# Result: WIN! 🎉
# Exploration Rate (epsilon): 0.0100
#
# Hand 45/100
# Current record - Wins: 19 | Losses: 19 | Pushes: 6
#
# ==================================================
# Dealer shows: 9 of Clubs
# AI's hand: 4 of Spades, 3 of Spades
#
# AI's decision: Hit
# ==================================================
#
# ==================================================
# Dealer shows: 9 of Clubs
# AI's hand: 4 of Spades, 3 of Spades, 5 of Hearts
#
# AI's decision: Stand
# ==================================================
#
# Final Hands:
#
# ==================================================
# Dealer's full hand: 9 of Clubs, 4 of Diamonds, A of Spades, 10 of Clubs
# AI's hand: 4 of Spades, 3 of Spades, 5 of Hearts
#
# AI's decision: Stand
# ==================================================
#
# Result: WIN! 🎉
# Exploration Rate (epsilon): 0.0100
#
# Hand 46/100
# Current record - Wins: 20 | Losses: 19 | Pushes: 6
#
# ==================================================
# Dealer shows: 7 of Clubs
# AI's hand: 7 of Diamonds, 5 of Spades
#
# AI's decision: Hit
# ==================================================
#
# ==================================================
# Dealer shows: 7 of Clubs
# AI's hand: 7 of Diamonds, 5 of Spades, 2 of Clubs
#
# AI's decision: Hit
# ==================================================
#
# ==================================================
# Dealer shows: 7 of Clubs
# AI's hand: 7 of Diamonds, 5 of Spades, 2 of Clubs, 7 of Hearts
#
# AI's decision: Stand
# ==================================================
#
# Final Hands:
#
# ==================================================
# Dealer's full hand: 7 of Clubs, K of Hearts
# AI's hand: 7 of Diamonds, 5 of Spades, 2 of Clubs, 7 of Hearts
#
# AI's decision: Stand
# ==================================================
#
# Result: WIN! 🎉
# Exploration Rate (epsilon): 0.0100
#
# Hand 47/100
# Current record - Wins: 21 | Losses: 19 | Pushes: 6
#
# ==================================================
# Dealer shows: A of Hearts
# AI's hand: 10 of Diamonds, 10 of Hearts
#
# AI's decision: Stand
# ==================================================
#
# Final Hands:
#
# ==================================================
# Dealer's full hand: A of Hearts, 6 of Diamonds
# AI's hand: 10 of Diamonds, 10 of Hearts
#
# AI's decision: Stand
# ==================================================
#
# Result: WIN! 🎉
# Exploration Rate (epsilon): 0.0100
#
# Hand 48/100
# Current record - Wins: 22 | Losses: 19 | Pushes: 6
#
# ==================================================
# Dealer shows: 10 of Spades
# AI's hand: K of Clubs, 10 of Hearts
#
# AI's decision: Stand
# ==================================================
#
# Final Hands:
#
# ==================================================
# Dealer's full hand: 10 of Spades, 8 of Hearts
# AI's hand: K of Clubs, 10 of Hearts
#
# AI's decision: Stand
# ==================================================
#
# Result: WIN! 🎉
# Exploration Rate (epsilon): 0.0100
#
# Hand 49/100
# Current record - Wins: 23 | Losses: 19 | Pushes: 6
#
# ==================================================
# Dealer shows: Q of Spades
# AI's hand: 3 of Diamonds, J of Clubs
#
# AI's decision: Hit
# ==================================================
#
# Final Hands:
#
# ==================================================
# Dealer's full hand: Q of Spades, A of Spades
# AI's hand: 3 of Diamonds, J of Clubs, Q of Diamonds
#
# AI's decision: Hit
# ==================================================
#
# Result: LOSS 😢
# Exploration Rate (epsilon): 0.0100
#
# Hand 50/100
# Current record - Wins: 23 | Losses: 20 | Pushes: 6
#
# ==================================================
# Dealer shows: J of Hearts
# AI's hand: 2 of Clubs, 6 of Hearts
#
# AI's decision: Hit
# ==================================================
#
# ==================================================
# Dealer shows: J of Hearts
# AI's hand: 2 of Clubs, 6 of Hearts, 4 of Spades
#
# AI's decision: Hit
# ==================================================
#
# ==================================================
# Dealer shows: J of Hearts
# AI's hand: 2 of Clubs, 6 of Hearts, 4 of Spades, 4 of Clubs
#
# AI's decision: Stand
# ==================================================
#
# Final Hands:
#
# ==================================================
# Dealer's full hand: J of Hearts, 8 of Spades
# AI's hand: 2 of Clubs, 6 of Hearts, 4 of Spades, 4 of Clubs
#
# AI's decision: Stand
# ==================================================
#
# Result: LOSS 😢
# Exploration Rate (epsilon): 0.0100
#
# Hand 51/100
# Current record - Wins: 23 | Losses: 21 | Pushes: 6
#
# ==================================================
# Dealer shows: 2 of Hearts
# AI's hand: 9 of Clubs, 5 of Spades
#
# AI's decision: Hit
# ==================================================
#
# ==================================================
# Dealer shows: 2 of Hearts
# AI's hand: 9 of Clubs, 5 of Spades, 7 of Spades
#
# AI's decision: Stand
# ==================================================
#
# Final Hands:
#
# ==================================================
# Dealer's full hand: 2 of Hearts, 5 of Clubs, Q of Hearts
# AI's hand: 9 of Clubs, 5 of Spades, 7 of Spades
#
# AI's decision: Stand
# ==================================================
#
# Result: WIN! 🎉
# Exploration Rate (epsilon): 0.0100
#
# Hand 52/100
# Current record - Wins: 24 | Losses: 21 | Pushes: 6
#
# ==================================================
# Dealer shows: 5 of Diamonds
# AI's hand: 3 of Clubs, 7 of Hearts
#
# AI's decision: Hit
# ==================================================
#
# ==================================================
# Dealer shows: 5 of Diamonds
# AI's hand: 3 of Clubs, 7 of Hearts, A of Hearts
#
# AI's decision: Stand
# ==================================================
#
# Final Hands:
#
# ==================================================
# Dealer's full hand: 5 of Diamonds, J of Spades, 7 of Diamonds
# AI's hand: 3 of Clubs, 7 of Hearts, A of Hearts
#
# AI's decision: Stand
# ==================================================
#
# Result: WIN! 🎉
# Exploration Rate (epsilon): 0.0100
#
# Hand 53/100
# Current record - Wins: 25 | Losses: 21 | Pushes: 6
#
# ==================================================
# Dealer shows: K of Clubs
# AI's hand: 2 of Spades, 4 of Hearts
#
# AI's decision: Hit
# ==================================================
#
# ==================================================
# Dealer shows: K of Clubs
# AI's hand: 2 of Spades, 4 of Hearts, 9 of Diamonds
#
# AI's decision: Hit
# ==================================================
#
# ==================================================
# Dealer shows: K of Clubs
# AI's hand: 2 of Spades, 4 of Hearts, 9 of Diamonds, 3 of Hearts
#
# AI's decision: Stand
# ==================================================
#
# Final Hands:
#
# ==================================================
# Dealer's full hand: K of Clubs, 9 of Spades
# AI's hand: 2 of Spades, 4 of Hearts, 9 of Diamonds, 3 of Hearts
#
# AI's decision: Stand
# ==================================================
#
# Result: LOSS 😢
# Exploration Rate (epsilon): 0.0100
#
# Hand 54/100
# Current record - Wins: 25 | Losses: 22 | Pushes: 6
#
# ==================================================
# Dealer shows: Q of Clubs
# AI's hand: A of Diamonds, K of Spades
#
# AI's decision: Stand
# ==================================================
#
# Final Hands:
#
# ==================================================
# Dealer's full hand: Q of Clubs, 10 of Spades
# AI's hand: A of Diamonds, K of Spades
#
# AI's decision: Stand
# ==================================================
#
# Result: PUSH (Tie) 🤝
# Exploration Rate (epsilon): 0.0100
#
# Hand 55/100
# Current record - Wins: 25 | Losses: 22 | Pushes: 7
#
# ==================================================
# Dealer shows: 8 of Diamonds
# AI's hand: 6 of Diamonds, A of Clubs
#
# AI's decision: Double Down
# ==================================================
#
# Final Hands:
#
# ==================================================
# Dealer's full hand: 8 of Diamonds, 3 of Spades, 5 of Hearts, J of Diamonds
# AI's hand: 6 of Diamonds, A of Clubs, 6 of Spades
#
# AI's decision: Double Down
# ==================================================
#
# Result: WIN! 🎉
# Exploration Rate (epsilon): 0.0100
#
# Hand 56/100
# Current record - Wins: 26 | Losses: 22 | Pushes: 7
#
# ==================================================
# Dealer shows: 6 of Clubs
# AI's hand: 9 of Hearts, K of Hearts
#
# AI's decision: Stand
# ==================================================
#
# Final Hands:
#
# ==================================================
# Dealer's full hand: 6 of Clubs, 7 of Clubs, 2 of Diamonds, K of Diamonds
# AI's hand: 9 of Hearts, K of Hearts
#
# AI's decision: Stand
# ==================================================
#
# Result: WIN! 🎉
# Exploration Rate (epsilon): 0.0100
#
# Hand 57/100
# Current record - Wins: 27 | Losses: 22 | Pushes: 7
#
# ==================================================
# Dealer shows: 8 of Clubs
# AI's hand: 4 of Diamonds, 10 of Diamonds
#
# AI's decision: Hit
# ==================================================
#
# Final Hands:
#
# ==================================================
# Dealer's full hand: 8 of Clubs, 10 of Clubs
# AI's hand: 4 of Diamonds, 10 of Diamonds, K of Diamonds
#
# AI's decision: Hit
# ==================================================
#
# Result: LOSS 😢
# Exploration Rate (epsilon): 0.0100
#
# Hand 58/100
# Current record - Wins: 27 | Losses: 23 | Pushes: 7
#
# ==================================================
# Dealer shows: 6 of Hearts
# AI's hand: K of Clubs, 8 of Hearts
#
# AI's decision: Stand
# ==================================================
#
# Final Hands:
#
# ==================================================
# Dealer's full hand: 6 of Hearts, 4 of Diamonds, 7 of Spades
# AI's hand: K of Clubs, 8 of Hearts
#
# AI's decision: Stand
# ==================================================
#
# Result: WIN! 🎉
# Exploration Rate (epsilon): 0.0100
#
# Hand 59/100
# Current record - Wins: 28 | Losses: 23 | Pushes: 7
#
# ==================================================
# Dealer shows: 7 of Clubs
# AI's hand: 10 of Diamonds, 2 of Hearts
#
# AI's decision: Hit
# ==================================================
#
# ==================================================
# Dealer shows: 7 of Clubs
# AI's hand: 10 of Diamonds, 2 of Hearts, 8 of Diamonds
#
# AI's decision: Stand
# ==================================================
#
# Final Hands:
#
# ==================================================
# Dealer's full hand: 7 of Clubs, 8 of Spades, Q of Diamonds
# AI's hand: 10 of Diamonds, 2 of Hearts, 8 of Diamonds
#
# AI's decision: Stand
# ==================================================
#
# Result: WIN! 🎉
# Exploration Rate (epsilon): 0.0100
#
# Hand 60/100
# Current record - Wins: 29 | Losses: 23 | Pushes: 7
#
# ==================================================
# Dealer shows: 9 of Spades
# AI's hand: J of Clubs, A of Spades
#
# AI's decision: Stand
# ==================================================
#
# Final Hands:
#
# ==================================================
# Dealer's full hand: 9 of Spades, 6 of Clubs
# AI's hand: J of Clubs, A of Spades
#
# AI's decision: Stand
# ==================================================
#
# Result: PUSH (Tie) 🤝
# Exploration Rate (epsilon): 0.0100
#
# Hand 61/100
# Current record - Wins: 29 | Losses: 23 | Pushes: 8
#
# ==================================================
# Dealer shows: 9 of Clubs
# AI's hand: 4 of Clubs, A of Hearts
#
# AI's decision: Hit
# ==================================================
#
# ==================================================
# Dealer shows: 9 of Clubs
# AI's hand: 4 of Clubs, A of Hearts, J of Hearts
#
# AI's decision: Double Down
# ==================================================
#
# Final Hands:
#
# ==================================================
# Dealer's full hand: 9 of Clubs, 3 of Spades
# AI's hand: 4 of Clubs, A of Hearts, J of Hearts
#
# AI's decision: Double Down
# ==================================================
#
# Result: LOSS 😢
# Exploration Rate (epsilon): 0.0100
#
# Hand 62/100
# Current record - Wins: 29 | Losses: 24 | Pushes: 8
#
# ==================================================
# Dealer shows: J of Diamonds
# AI's hand: 10 of Hearts, 3 of Clubs
#
# AI's decision: Hit
# ==================================================
#
# ==================================================
# Dealer shows: J of Diamonds
# AI's hand: 10 of Hearts, 3 of Clubs, 5 of Hearts
#
# AI's decision: Stand
# ==================================================
#
# Final Hands:
#
# ==================================================
# Dealer's full hand: J of Diamonds, 3 of Diamonds, 4 of Hearts
# AI's hand: 10 of Hearts, 3 of Clubs, 5 of Hearts
#
# AI's decision: Stand
# ==================================================
#
# Result: WIN! 🎉
# Exploration Rate (epsilon): 0.0100
#
# Hand 63/100
# Current record - Wins: 30 | Losses: 24 | Pushes: 8
#
# ==================================================
# Dealer shows: K of Hearts
# AI's hand: 7 of Diamonds, 2 of Spades
#
# AI's decision: Hit
# ==================================================
#
# ==================================================
# Dealer shows: K of Hearts
# AI's hand: 7 of Diamonds, 2 of Spades, 5 of Clubs
#
# AI's decision: Hit
# ==================================================
#
# ==================================================
# Dealer shows: K of Hearts
# AI's hand: 7 of Diamonds, 2 of Spades, 5 of Clubs, 7 of Hearts
#
# AI's decision: Stand
# ==================================================
#
# Final Hands:
#
# ==================================================
# Dealer's full hand: K of Hearts, 6 of Diamonds, 10 of Clubs
# AI's hand: 7 of Diamonds, 2 of Spades, 5 of Clubs, 7 of Hearts
#
# AI's decision: Stand
# ==================================================
#
# Result: WIN! 🎉
# Exploration Rate (epsilon): 0.0100
#
# Hand 64/100
# Current record - Wins: 31 | Losses: 24 | Pushes: 8
#
# ==================================================
# Dealer shows: 9 of Hearts
# AI's hand: 6 of Spades, Q of Hearts
#
# AI's decision: Stand
# ==================================================
#
# Final Hands:
#
# ==================================================
# Dealer's full hand: 9 of Hearts, A of Diamonds
# AI's hand: 6 of Spades, Q of Hearts
#
# AI's decision: Stand
# ==================================================
#
# Result: LOSS 😢
# Exploration Rate (epsilon): 0.0100
#
# Hand 65/100
# Current record - Wins: 31 | Losses: 25 | Pushes: 8
#
# ==================================================
# Dealer shows: 5 of Spades
# AI's hand: J of Spades, 5 of Diamonds
#
# AI's decision: Double Down
# ==================================================
#
# Final Hands:
#
# ==================================================
# Dealer's full hand: 5 of Spades, 4 of Spades
# AI's hand: J of Spades, 5 of Diamonds, Q of Spades
#
# AI's decision: Double Down
# ==================================================
#
# Result: LOSS 😢
# Exploration Rate (epsilon): 0.0100
#
# Hand 66/100
# Current record - Wins: 31 | Losses: 26 | Pushes: 8
#
# ==================================================
# Dealer shows: 10 of Spades
# AI's hand: A of Clubs, 3 of Hearts
#
# AI's decision: Hit
# ==================================================
#
# ==================================================
# Dealer shows: 10 of Spades
# AI's hand: A of Clubs, 3 of Hearts, Q of Clubs
#
# AI's decision: Hit
# ==================================================
#
# ==================================================
# Dealer shows: 10 of Spades
# AI's hand: A of Clubs, 3 of Hearts, Q of Clubs, 2 of Clubs
#
# AI's decision: Stand
# ==================================================
#
# Final Hands:
#
# ==================================================
# Dealer's full hand: 10 of Spades, 8 of Clubs
# AI's hand: A of Clubs, 3 of Hearts, Q of Clubs, 2 of Clubs
#
# AI's decision: Stand
# ==================================================
#
# Result: LOSS 😢
# Exploration Rate (epsilon): 0.0100
#
# Hand 67/100
# Current record - Wins: 31 | Losses: 27 | Pushes: 8
#
# ==================================================
# Dealer shows: 2 of Diamonds
# AI's hand: 9 of Diamonds, K of Spades
#
# AI's decision: Stand
# ==================================================
#
# Final Hands:
#
# ==================================================
# Dealer's full hand: 2 of Diamonds, K of Clubs, 6 of Diamonds
# AI's hand: 9 of Diamonds, K of Spades
#
# AI's decision: Stand
# ==================================================
#
# Result: WIN! 🎉
# Exploration Rate (epsilon): 0.0100
#
# Hand 68/100
# Current record - Wins: 32 | Losses: 27 | Pushes: 8
#
# ==================================================
# Dealer shows: 9 of Clubs
# AI's hand: 2 of Spades, K of Spades
#
# AI's decision: Stand
# ==================================================
#
# Final Hands:
#
# ==================================================
# Dealer's full hand: 9 of Clubs, J of Diamonds
# AI's hand: 2 of Spades, K of Spades
#
# AI's decision: Stand
# ==================================================
#
# Result: LOSS 😢
# Exploration Rate (epsilon): 0.0100
#
# Hand 69/100
# Current record - Wins: 32 | Losses: 28 | Pushes: 8
#
# ==================================================
# Dealer shows: 3 of Hearts
# AI's hand: 2 of Clubs, 5 of Hearts
#
# AI's decision: Hit
# ==================================================
#
# ==================================================
# Dealer shows: 3 of Hearts
# AI's hand: 2 of Clubs, 5 of Hearts, 7 of Diamonds
#
# AI's decision: Hit
# ==================================================
#
# Final Hands:
#
# ==================================================
# Dealer's full hand: 3 of Hearts, 7 of Spades
# AI's hand: 2 of Clubs, 5 of Hearts, 7 of Diamonds, 10 of Spades
#
# AI's decision: Hit
# ==================================================
#
# Result: LOSS 😢
# Exploration Rate (epsilon): 0.0100
#
# Hand 70/100
# Current record - Wins: 32 | Losses: 29 | Pushes: 8
#
# ==================================================
# Dealer shows: 8 of Diamonds
# AI's hand: 7 of Clubs, Q of Clubs
#
# AI's decision: Stand
# ==================================================
#
# Final Hands:
#
# ==================================================
# Dealer's full hand: 8 of Diamonds, 5 of Diamonds, 2 of Diamonds, 4 of Hearts
# AI's hand: 7 of Clubs, Q of Clubs
#
# AI's decision: Stand
# ==================================================
#
# Result: LOSS 😢
# Exploration Rate (epsilon): 0.0100
#
# Hand 71/100
# Current record - Wins: 32 | Losses: 30 | Pushes: 8
#
# ==================================================
# Dealer shows: 6 of Hearts
# AI's hand: J of Clubs, A of Diamonds
#
# AI's decision: Stand
# ==================================================
#
# Final Hands:
#
# ==================================================
# Dealer's full hand: 6 of Hearts, 8 of Spades
# AI's hand: J of Clubs, A of Diamonds
#
# AI's decision: Stand
# ==================================================
#
# Result: PUSH (Tie) 🤝
# Exploration Rate (epsilon): 0.0100
#
# Hand 72/100
# ...
#
# ==================================================
# Dealer shows: 4 of Spades
# AI's hand: 4 of Diamonds, Q of Hearts
#
# AI's decision: Stand
# ==================================================
#
# Final Hands:
#
# ==================================================
# Dealer's full hand: 4 of Spades, 2 of Hearts, 6 of Spades, A of Hearts, 4 of Clubs
# AI's hand: 4 of Diamonds, Q of Hearts
#
# AI's decision: Stand
# ==================================================
#
# Result: LOSS 😢
# Exploration Rate (epsilon): 0.0100
#
# Hand 76/100
# Current record - Wins: 33 | Losses: 33 | Pushes: 9
#
# ==================================================
# Dealer shows: 3 of Clubs
# AI's hand: 8 of Hearts, 8 of Clubs
#
# AI's decision: Hit
# ==================================================
#
# ==================================================
# Dealer shows: 3 of Clubs
# AI's hand: 8 of Hearts, 8 of Clubs, 5 of Clubs
#
# AI's decision: Stand
# ==================================================
#
# Final Hands:
#
# ==================================================
# Dealer's full hand: 3 of Clubs, 3 of Diamonds, 9 of Hearts, 5 of Spades
# AI's hand: 8 of Hearts, 8 of Clubs, 5 of Clubs
#
# AI's decision: Stand
# ==================================================
#
# Result: WIN! 🎉
# Exploration Rate (epsilon): 0.0100
#
# Hand 77/100
# Current record - Wins: 34 | Losses: 33 | Pushes: 9
#
# ==================================================
# Dealer shows: 10 of Hearts
# AI's hand: K of Diamonds, 10 of Hearts
#
# AI's decision: Stand
# ==================================================
#
# Final Hands:
#
# ==================================================
# Dealer's full hand: 10 of Hearts, 7 of Hearts
# AI's hand: K of Diamonds, 10 of Hearts
#
# AI's decision: Stand
# ==================================================
#
# Result: WIN! 🎉
# Exploration Rate (epsilon): 0.0100
#
# Hand 78/100
# Current record - Wins: 35 | Losses: 33 | Pushes: 9
#
# ==================================================
# Dealer shows: 3 of Spades
# AI's hand: A of Clubs, 10 of Diamonds
#
# AI's decision: Stand
# ==================================================
#
# Final Hands:
#
# ==================================================
# Dealer's full hand: 3 of Spades, 9 of Hearts
# AI's hand: A of Clubs, 10 of Diamonds
#
# AI's decision: Stand
# ==================================================
#
# Result: PUSH (Tie) 🤝
# Exploration Rate (epsilon): 0.0100
#
# Hand 79/100
# Current record - Wins: 35 | Losses: 33 | Pushes: 10
#
# ==================================================
# Dealer shows: J of Hearts
# AI's hand: 7 of Clubs, A of Diamonds
#
# AI's decision: Stand
# ==================================================
#
# Final Hands:
#
# ==================================================
# Dealer's full hand: J of Hearts, 2 of Diamonds, 3 of Clubs, 3 of Diamonds
# AI's hand: 7 of Clubs, A of Diamonds
#
# AI's decision: Stand
# ==================================================
#
# Result: PUSH (Tie) 🤝
# Exploration Rate (epsilon): 0.0100
#
# Hand 80/100
# Current record - Wins: 35 | Losses: 33 | Pushes: 11
#
# ==================================================
# Dealer shows: J of Clubs
# AI's hand: 6 of Clubs, 2 of Clubs
#
# AI's decision: Hit
# ==================================================
#
# ==================================================
# Dealer shows: J of Clubs
# AI's hand: 6 of Clubs, 2 of Clubs, K of Hearts
#
# AI's decision: Stand
# ==================================================
#
# Final Hands:
#
# ==================================================
# Dealer's full hand: J of Clubs, 10 of Spades
# AI's hand: 6 of Clubs, 2 of Clubs, K of Hearts
#
# AI's decision: Stand
# ==================================================
#
# Result: LOSS 😢
# Exploration Rate (epsilon): 0.0100
#
# Hand 81/100
# Current record - Wins: 35 | Losses: 34 | Pushes: 11
#
# ==================================================
# Dealer shows: 8 of Clubs
# AI's hand: 5 of Clubs, 2 of Spades
#
# AI's decision: Hit
# ==================================================
#
# ==================================================
# Dealer shows: 8 of Clubs
# AI's hand: 5 of Clubs, 2 of Spades, 3 of Hearts
#
# AI's decision: Hit
# ==================================================
#
# ==================================================
# Dealer shows: 8 of Clubs
# AI's hand: 5 of Clubs, 2 of Spades, 3 of Hearts, 5 of Diamonds
#
# AI's decision: Stand
# ==================================================
#
# Final Hands:
#
# ==================================================
# Dealer's full hand: 8 of Clubs, 5 of Spades, 10 of Clubs
# AI's hand: 5 of Clubs, 2 of Spades, 3 of Hearts, 5 of Diamonds
#
# AI's decision: Stand
# ==================================================
#
# Result: WIN! 🎉
# Exploration Rate (epsilon): 0.0100
#
# Hand 82/100
# Current record - Wins: 36 | Losses: 34 | Pushes: 11
#
# ==================================================
# Dealer shows: 4 of Clubs
# AI's hand: Q of Spades, A of Spades
#
# AI's decision: Stand
# ==================================================
#
# Final Hands:
#
# ==================================================
# Dealer's full hand: 4 of Clubs, 8 of Spades
# AI's hand: Q of Spades, A of Spades
#
# AI's decision: Stand
# ==================================================
#
# Result: PUSH (Tie) 🤝
# Exploration Rate (epsilon): 0.0100
#
# Hand 83/100
# Current record - Wins: 36 | Losses: 34 | Pushes: 12
#
# ==================================================
# Dealer shows: 4 of Hearts
# AI's hand: A of Hearts, 4 of Spades
#
# AI's decision: Double Down
# ==================================================
#
# Final Hands:
#
# ==================================================
# Dealer's full hand: 4 of Hearts, J of Diamonds, 9 of Diamonds
# AI's hand: A of Hearts, 4 of Spades, Q of Hearts
#
# AI's decision: Double Down
# ==================================================
#
# Result: WIN! 🎉
# Exploration Rate (epsilon): 0.0100
#
# Hand 84/100
# Current record - Wins: 37 | Losses: 34 | Pushes: 12
#
# ==================================================
# Dealer shows: 7 of Spades
# AI's hand: 9 of Spades, 8 of Diamonds
#
# AI's decision: Stand
# ==================================================
#
# Final Hands:
#
# ==================================================
# Dealer's full hand: 7 of Spades, 2 of Hearts, K of Clubs
# AI's hand: 9 of Spades, 8 of Diamonds
#
# AI's decision: Stand
# ==================================================
#
# Result: LOSS 😢
# Exploration Rate (epsilon): 0.0100
#
# Hand 85/100
# Current record - Wins: 37 | Losses: 35 | Pushes: 12
#
# ==================================================
# Dealer shows: 6 of Hearts
# AI's hand: K of Spades, 4 of Diamonds
#
# AI's decision: Stand
# ==================================================
#
# Final Hands:
#
# ==================================================
# Dealer's full hand: 6 of Hearts, 9 of Clubs, 8 of Hearts
# AI's hand: K of Spades, 4 of Diamonds
#
# AI's decision: Stand
# ==================================================
#
# Result: WIN! 🎉
# Exploration Rate (epsilon): 0.0100
#
# Hand 86/100
# Current record - Wins: 38 | Losses: 35 | Pushes: 12
#
# ==================================================
# Dealer shows: Q of Diamonds
# AI's hand: 6 of Diamonds, Q of Clubs
#
# AI's decision: Stand
# ==================================================
#
# Final Hands:
#
# ==================================================
# Dealer's full hand: Q of Diamonds, 7 of Diamonds
# AI's hand: 6 of Diamonds, Q of Clubs
#
# AI's decision: Stand
# ==================================================
#
# Result: LOSS 😢
# Exploration Rate (epsilon): 0.0100
#
# Hand 87/100
# Current record - Wins: 38 | Losses: 36 | Pushes: 12
#
# ==================================================
# Dealer shows: 6 of Spades
# AI's hand: K of Diamonds, 5 of Hearts
#
# AI's decision: Hit
# ==================================================
#
# Final Hands:
#
# ==================================================
# Dealer's full hand: 6 of Spades, J of Spades
# AI's hand: K of Diamonds, 5 of Hearts, J of Spades
#
# AI's decision: Hit
# ==================================================
#
# Result: LOSS 😢
# Exploration Rate (epsilon): 0.0100
#
# Hand 88/100
# Current record - Wins: 38 | Losses: 37 | Pushes: 12
#
# ==================================================
# Dealer shows: Q of Clubs
# AI's hand: K of Clubs, 10 of Diamonds
#
# AI's decision: Stand
# ==================================================
#
# Final Hands:
#
# ==================================================
# Dealer's full hand: Q of Clubs, 9 of Diamonds
# AI's hand: K of Clubs, 10 of Diamonds
#
# AI's decision: Stand
# ==================================================
#
# Result: WIN! 🎉
# Exploration Rate (epsilon): 0.0100
#
# Hand 89/100
# Current record - Wins: 39 | Losses: 37 | Pushes: 12
#
# ==================================================
# Dealer shows: 7 of Clubs
# AI's hand: J of Clubs, A of Diamonds
#
# AI's decision: Stand
# ==================================================
#
# Final Hands:
#
# ==================================================
# Dealer's full hand: 7 of Clubs, 5 of Spades
# AI's hand: J of Clubs, A of Diamonds
#
# AI's decision: Stand
# ==================================================
#
# Result: PUSH (Tie) 🤝
# Exploration Rate (epsilon): 0.0100
#
# Hand 90/100
# Current record - Wins: 39 | Losses: 37 | Pushes: 13
#
# ==================================================
# Dealer shows: 4 of Hearts
# AI's hand: 2 of Spades, 10 of Spades
#
# AI's decision: Double Down
# ==================================================
#
# Final Hands:
#
# ==================================================
# Dealer's full hand: 4 of Hearts, 2 of Clubs, A of Spades
# AI's hand: 2 of Spades, 10 of Spades, 8 of Clubs
#
# AI's decision: Double Down
# ==================================================
#
# Result: WIN! 🎉
# Exploration Rate (epsilon): 0.0100
#
# Hand 91/100
# Current record - Wins: 40 | Losses: 37 | Pushes: 13
#
# ==================================================
# Dealer shows: 5 of Hearts
# AI's hand: 6 of Clubs, Q of Diamonds
#
# AI's decision: Stand
# ==================================================
#
# Final Hands:
#
# ==================================================
# Dealer's full hand: 5 of Hearts, 10 of Clubs, A of Clubs, 7 of Diamonds
# AI's hand: 6 of Clubs, Q of Diamonds
#
# AI's decision: Stand
# ==================================================
#
# Result: WIN! 🎉
# Exploration Rate (epsilon): 0.0100
#
# Hand 92/100
# Current record - Wins: 41 | Losses: 37 | Pushes: 13
#
# ==================================================
# Dealer shows: 9 of Hearts
# AI's hand: 5 of Diamonds, 3 of Diamonds
#
# AI's decision: Hit
# ==================================================
#
# ==================================================
# Dealer shows: 9 of Hearts
# AI's hand: 5 of Diamonds, 3 of Diamonds, J of Hearts
#
# AI's decision: Stand
# ==================================================
#
# Final Hands:
#
# ==================================================
# Dealer's full hand: 9 of Hearts, 6 of Diamonds, K of Hearts
# AI's hand: 5 of Diamonds, 3 of Diamonds, J of Hearts
#
# AI's decision: Stand
# ==================================================
#
# Result: WIN! 🎉
# Exploration Rate (epsilon): 0.0100
#
# Hand 93/100
# Current record - Wins: 42 | Losses: 37 | Pushes: 13
#
# ==================================================
# Dealer shows: 7 of Hearts
# AI's hand: 9 of Spades, J of Diamonds
#
# AI's decision: Stand
# ==================================================
#
# Final Hands:
#
# ==================================================
# Dealer's full hand: 7 of Hearts, Q of Spades
# AI's hand: 9 of Spades, J of Diamonds
#
# AI's decision: Stand
# ==================================================
#
# Result: WIN! 🎉
# Exploration Rate (epsilon): 0.0100
#
# Hand 94/100
# Current record - Wins: 43 | Losses: 37 | Pushes: 13
#
# ==================================================
# Dealer shows: A of Hearts
# AI's hand: 2 of Hearts, 3 of Clubs
#
# AI's decision: Hit
# ==================================================
#
# ==================================================
# Dealer shows: A of Hearts
# AI's hand: 2 of Hearts, 3 of Clubs, 7 of Spades
#
# AI's decision: Stand
# ==================================================
#
# Final Hands:
#
# ==================================================
# Dealer's full hand: A of Hearts, 8 of Diamonds
# AI's hand: 2 of Hearts, 3 of Clubs, 7 of Spades
#
# AI's decision: Stand
# ==================================================
#
# Result: LOSS 😢
# Exploration Rate (epsilon): 0.0100
#
# Hand 95/100
# Current record - Wins: 43 | Losses: 38 | Pushes: 13
#
# ==================================================
# Dealer shows: 10 of Hearts
# AI's hand: 8 of Spades, 6 of Hearts
#
# AI's decision: Hit
# ==================================================
#
# ==================================================
# Dealer shows: 10 of Hearts
# AI's hand: 8 of Spades, 6 of Hearts, 5 of Clubs
#
# AI's decision: Stand
# ==================================================
#
# Final Hands:
#
# ==================================================
# Dealer's full hand: 10 of Hearts, 2 of Diamonds, K of Spades
# AI's hand: 8 of Spades, 6 of Hearts, 5 of Clubs
#
# AI's decision: Stand
# ==================================================
#
# Result: WIN! 🎉
# Exploration Rate (epsilon): 0.0100
#
# Hand 96/100
# Current record - Wins: 44 | Losses: 38 | Pushes: 13
#
# ==================================================
# Dealer shows: 4 of Spades
# AI's hand: 4 of Diamonds, 8 of Hearts
#
# AI's decision: Double Down
# ==================================================
#
# Final Hands:
#
# ==================================================
# Dealer's full hand: 4 of Spades, 6 of Spades
# AI's hand: 4 of Diamonds, 8 of Hearts, K of Diamonds
#
# AI's decision: Double Down
# ==================================================
#
# Result: LOSS 😢
# Exploration Rate (epsilon): 0.0100
#
# Hand 97/100
# Current record - Wins: 44 | Losses: 39 | Pushes: 13
#
# ==================================================
# Dealer shows: Q of Hearts
# AI's hand: 3 of Spades, 9 of Clubs
#
# AI's decision: Hit
# ==================================================
#
# ==================================================
# Dealer shows: Q of Hearts
# AI's hand: 3 of Spades, 9 of Clubs, 4 of Clubs
#
# AI's decision: Stand
# ==================================================
#
# Final Hands:
#
# ==================================================
# Dealer's full hand: Q of Hearts, 3 of Hearts, 10 of Clubs
# AI's hand: 3 of Spades, 9 of Clubs, 4 of Clubs
#
# AI's decision: Stand
# ==================================================
#
# Result: WIN! 🎉
# Exploration Rate (epsilon): 0.0100
#
# Hand 98/100
# Current record - Wins: 45 | Losses: 39 | Pushes: 13
#
# ==================================================
# Dealer shows: 5 of Hearts
# AI's hand: A of Spades, Q of Spades
#
# AI's decision: Stand
# ==================================================
#
# Final Hands:
#
# ==================================================
# Dealer's full hand: 5 of Hearts, 10 of Hearts
# AI's hand: A of Spades, Q of Spades
#
# AI's decision: Stand
# ==================================================
#
# Result: PUSH (Tie) 🤝
# Exploration Rate (epsilon): 0.0100
#
# Hand 99/100
# Current record - Wins: 45 | Losses: 39 | Pushes: 14
#
# ==================================================
# Dealer shows: K of Hearts
# AI's hand: 8 of Spades, 3 of Diamonds
#
# AI's decision: Hit
# ==================================================
#
# ==================================================
# Dealer shows: K of Hearts
# AI's hand: 8 of Spades, 3 of Diamonds, J of Diamonds
#
# AI's decision: Stand
# ==================================================
#
# Final Hands:
#
# ==================================================
# Dealer's full hand: K of Hearts, 6 of Hearts, 7 of Spades
# AI's hand: 8 of Spades, 3 of Diamonds, J of Diamonds
#
# AI's decision: Stand
# ==================================================
#
# Result: WIN! 🎉
# Exploration Rate (epsilon): 0.0100
#
# Hand 100/100
# Current record - Wins: 46 | Losses: 39 | Pushes: 14
#
# ==================================================
# Dealer shows: 4 of Spades
# AI's hand: 5 of Spades, 8 of Clubs
#
# AI's decision: Double Down
# ==================================================
#
# Final Hands:
#
# ==================================================
# Dealer's full hand: 4 of Spades, 3 of Hearts
# AI's hand: 5 of Spades, 8 of Clubs, 9 of Clubs
#
# AI's decision: Double Down
# ==================================================
#
# Result: LOSS 😢
# Exploration Rate (epsilon): 0.0100
#
# Final Statistics:
# Total Wins: 46
# Total Losses: 40
# Total Pushes: 14
# Win Rate: 46.00%
# Final Exploration Rate: 0.0100

# %%
from blackjack_ai.agents import QLearningAgent, BasicStrategyAgent, RandomAgent
from blackjack_ai.environment import BlackjackEnv
from scipy.stats import binomtest

N_GAMES = 1000

def run_agent(agent, n_games=N_GAMES):
    env = BlackjackEnv()
    wins = losses = pushes = 0
    for _ in range(n_games):
        state = env.reset()
        done = False
        while not done:
            action = agent.get_action(state, is_training=False)
            next_state, reward, done, _ = env.step(action)
            state = next_state
        if reward > 0:
            wins += 1
        elif reward < 0:
            losses += 1
        else:
            pushes += 1
    return wins, losses, pushes

# If you have a trained QLearningAgent, load it here
try:
    q_agent = QLearningAgent()
    q_agent.load_policy("trained_policy.npy")
except Exception:
    q_agent = QLearningAgent()  # fallback if no policy

agents = [
    ("Q-Learning", q_agent),
    ("Basic Strategy", BasicStrategyAgent()),
    ("Random", RandomAgent())
]

results = []
for name, agent in agents:
    wins, losses, pushes = run_agent(agent, N_GAMES)
    win_rate = wins / N_GAMES
    pval = binomtest(wins, N_GAMES, 0.42, alternative='two-sided').pvalue
    results.append((name, wins, losses, pushes, win_rate, pval))

print("\n=== Baseline Comparison (1000 games each) ===")
for name, wins, losses, pushes, win_rate, pval in results:
    print(f"\n{name} Agent:")
    print(f"  Wins:   {wins} ({win_rate:.2%})")
    print(f"  Losses: {losses}")
    print(f"  Pushes: {pushes}")
    print(f"  p-value vs 42% win rate: {pval:.4f}")
# Out:
# === Baseline Comparison (1000 games each) ===
#
# Q-Learning Agent:
#   Wins:   377 (37.70%)
#   Losses: 497
#   Pushes: 126
#   p-value vs 42% win rate: 0.0059
#
# Basic Strategy Agent:
#   Wins:   390 (39.00%)
#   Losses: 482
#   Pushes: 128
#   p-value vs 42% win rate: 0.0546
#
# Random Agent:
#   Wins:   239 (23.90%)
#   Losses: 684
#   Pushes: 77
#   p-value vs 42% win rate: 0.0000
